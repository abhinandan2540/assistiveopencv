# %% [markdown]
# model updation for voice output
#
# model testing on videos

# %%
import cv2
import pyttsx3
import threading
import queue
from ultralytics import YOLO
 
# model loading 
model = YOLO("best.pt")

# Speech queue
speech_queue = queue.Queue()

# pyttsx3 
engine = pyttsx3.init('sapi5')
engine.setProperty("rate", 155)


def speech_worker():
    while True:
        text = speech_queue.get()
        if text is None:
            break
        engine.say(text)
        engine.runAndWait()
        speech_queue.task_done()


# speech threading
threading.Thread(target=speech_worker, daemon=True).start()


def speak(text):
    speech_queue.put(text)


# thresholds
CLOSE_AREA = 55000
FRAME_CENTER_ZONE = 80

video_path = "custom/vid_4.mp4"
cap = cv2.VideoCapture(video_path)

last_decision = None

# custom messages for each class
class_warnings = {
    0: "Bike ahead",
    1: "Car ahead",
    2: "Cycle ahead",
    3: "Pole ahead",
    4: "Object ahead",
    5: "Pothole ahead, step carefully",
    6: "Scooty ahead",
    7: "Stairs ahead, step carefully",
    8: "Tree ahead",
}

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]
    decision = "Path Clear"
    warning = None

    # bounding boxes
    for box in results.boxes:
        cls = int(box.cls)
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        area = (x2 - x1) * (y2 - y1)

        obj_center_x = (x1 + x2) // 2
        frame_center_x = frame.shape[1] // 2

        # warning message for each classes
        if cls in class_warnings:
            warning = class_warnings[cls]

        # distance logic
        if area > CLOSE_AREA:
            decision = "Stop, obstacle very close"
        else:
            # direction logic
            if obj_center_x < frame_center_x - FRAME_CENTER_ZONE:
                decision = "Move Right"
            elif obj_center_x > frame_center_x + FRAME_CENTER_ZONE:
                decision = "Move Left"

    # final message : distance + direction
    if decision == "Path Clear":
        final_message = "Path Clear"
    else:
        final_message = (warning + ", " + decision) if warning else decision

    if final_message != last_decision:
        print("Speaking:", final_message)
        speak(final_message)
        last_decision = final_message

    annotated_frame = results.plot()
    cv2.putText(annotated_frame, final_message, (30, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 0), 3)

    cv2.imshow("Assistive Vision System", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 391.9ms
# Speed: 12.8ms preprocess, 391.9ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Bike ahead, Move Right
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 241.6ms
# Speed: 3.8ms preprocess, 241.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 231.2ms
# Speed: 2.6ms preprocess, 231.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 232.5ms
# Speed: 2.9ms preprocess, 232.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 211.9ms
# Speed: 2.7ms preprocess, 211.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 179.1ms
# Speed: 3.4ms preprocess, 179.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 175.7ms
# Speed: 1.9ms preprocess, 175.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 192.4ms
# Speed: 3.6ms preprocess, 192.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 1 stairs, 193.8ms
# Speed: 2.1ms preprocess, 193.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Stairs ahead, step carefully, Move Left
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 1 stairs, 170.9ms
# Speed: 3.9ms preprocess, 170.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 1 stairs, 170.1ms
# Speed: 2.8ms preprocess, 170.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 182.2ms
# Speed: 2.4ms preprocess, 182.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Bike ahead, Move Right
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 217.1ms
# Speed: 2.8ms preprocess, 217.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 201.2ms
# Speed: 2.8ms preprocess, 201.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 194.9ms
# Speed: 2.3ms preprocess, 194.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Bike ahead, Move Right
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 196.8ms
# Speed: 4.4ms preprocess, 196.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 196.2ms
# Speed: 2.3ms preprocess, 196.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 234.3ms
# Speed: 2.3ms preprocess, 234.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 219.4ms
# Speed: 2.8ms preprocess, 219.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 216.2ms
# Speed: 2.2ms preprocess, 216.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 203.9ms
# Speed: 2.8ms preprocess, 203.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bikes, 3 cycles, 1 scooty, 1048.6ms
# Speed: 2.4ms preprocess, 1048.6ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 347.6ms
# Speed: 28.6ms preprocess, 347.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 197.2ms
# Speed: 6.4ms preprocess, 197.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 176.5ms
# Speed: 1.9ms preprocess, 176.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 180.2ms
# Speed: 1.7ms preprocess, 180.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Bike ahead, Move Right
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 187.5ms
# Speed: 2.6ms preprocess, 187.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 174.2ms
# Speed: 2.2ms preprocess, 174.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 178.5ms
# Speed: 1.9ms preprocess, 178.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 183.9ms
# Speed: 2.3ms preprocess, 183.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 170.9ms
# Speed: 2.9ms preprocess, 170.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 305.3ms
# Speed: 2.7ms preprocess, 305.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 231.9ms
# Speed: 2.0ms preprocess, 231.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bikes, 2 cycles, 1 scooty, 249.4ms
# Speed: 5.6ms preprocess, 249.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 232.8ms
# Speed: 3.3ms preprocess, 232.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 233.5ms
# Speed: 3.1ms preprocess, 233.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 233.2ms
# Speed: 4.1ms preprocess, 233.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 3 bikes, 1 cycle, 1 scooty, 261.7ms
# Speed: 4.8ms preprocess, 261.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Bike ahead, Move Right
#
# 0: 384x640 4 bikes, 2 cycles, 1 scooty, 196.1ms
# Speed: 3.8ms preprocess, 196.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 169.4ms
# Speed: 1.9ms preprocess, 169.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 178.8ms
# Speed: 3.2ms preprocess, 178.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 180.1ms
# Speed: 1.8ms preprocess, 180.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Bike ahead, Move Right
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 196.0ms
# Speed: 4.0ms preprocess, 196.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 175.0ms
# Speed: 3.2ms preprocess, 175.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 193.0ms
# Speed: 1.9ms preprocess, 193.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 173.4ms
# Speed: 1.8ms preprocess, 173.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 171.7ms
# Speed: 2.0ms preprocess, 171.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 177.5ms
# Speed: 2.7ms preprocess, 177.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bikes, 3 cycles, 1 scooty, 172.4ms
# Speed: 1.8ms preprocess, 172.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 183.4ms
# Speed: 2.1ms preprocess, 183.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 169.8ms
# Speed: 2.8ms preprocess, 169.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 171.7ms
# Speed: 1.8ms preprocess, 171.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 172.0ms
# Speed: 2.0ms preprocess, 172.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 170.9ms
# Speed: 1.7ms preprocess, 170.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 176.1ms
# Speed: 2.0ms preprocess, 176.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 180.6ms
# Speed: 1.7ms preprocess, 180.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 172.9ms
# Speed: 1.9ms preprocess, 172.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 173.8ms
# Speed: 1.7ms preprocess, 173.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 5 cycles, 1 scooty, 179.7ms
# Speed: 1.9ms preprocess, 179.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 173.9ms
# Speed: 1.9ms preprocess, 173.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 187.3ms
# Speed: 1.9ms preprocess, 187.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 5 cycles, 1 scooty, 226.6ms
# Speed: 1.8ms preprocess, 226.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 5 cycles, 1 scooty, 209.9ms
# Speed: 3.1ms preprocess, 209.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 212.3ms
# Speed: 2.4ms preprocess, 212.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 210.9ms
# Speed: 2.4ms preprocess, 210.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 201.1ms
# Speed: 3.5ms preprocess, 201.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 3 cycles, 1 scooty, 218.1ms
# Speed: 3.5ms preprocess, 218.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 201.6ms
# Speed: 2.8ms preprocess, 201.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 5 cycles, 1 scooty, 756.7ms
# Speed: 62.3ms preprocess, 756.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 5 cycles, 1 scooty, 278.1ms
# Speed: 3.2ms preprocess, 278.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 4 cycles, 1 scooty, 248.1ms
# Speed: 2.4ms preprocess, 248.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 7 cycles, 1 scooty, 244.8ms
# Speed: 2.7ms preprocess, 244.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 5 cycles, 1 scooty, 225.9ms
# Speed: 2.3ms preprocess, 225.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bikes, 1 cycle, 1 scooty, 221.6ms
# Speed: 3.2ms preprocess, 221.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Left
#
# 0: 384x640 3 bikes, 2 cycles, 1 scooty, 315.7ms
# Speed: 2.2ms preprocess, 315.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Right
#
# 0: 384x640 3 bikes, 1 cycle, 1 scooty, 246.8ms
# Speed: 3.0ms preprocess, 246.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Speaking: Cycle ahead, Move Left
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
