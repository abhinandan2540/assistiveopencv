# %%
from ultralytics import YOLO
# loading pre trained model
# yolov8s trained on COCO dataset
model_yolov8s=YOLO("yolov8s.pt")

# %% [markdown]
# code is runned on google colab (T4 GPU)

# %%
# model training on new dataset
model_yolov8s_results=model_yolov8s.train(
    data='data.yaml',
    imgsz=640,
    epochs=50,
    batch=8,
    device=-1
)
# Out:
# requirements: Ultralytics requirement ['nvidia-ml-py>=12.0.0'] not found, attempting AutoUpdate...
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# requirements: AutoUpdate success  6.5s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
# WARNING Failed to initialize pynvml, GPU stats disabled: NVML Shared Library Not Found
# Searching for 1 idle GPUs with free memory >= 20.0% and free utilization >= 0.0%...
# WARNING NVML stats unavailable.
# Ultralytics 8.3.226  Python-3.13.1 torch-2.9.0+cpu CPU (11th Gen Intel Core(TM) i3-1115G4 3.00GHz)
# ...
