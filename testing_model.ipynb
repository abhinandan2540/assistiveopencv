# %%
from ultralytics import YOLO
best_model=YOLO("best.pt") # loading model

result_list = best_model('custom/stairs.jpeg') # testing on images
result=result_list[0]
result.show()
# Out:
# image 1/1 c:\Users\USER\assistiveopencv\custom\stairs.jpeg: 320x640 1 stairs, 155.3ms
# Speed: 3.6ms preprocess, 155.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
